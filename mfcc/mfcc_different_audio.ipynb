# %%
import librosa
audio_path_m = './REC20200222223320.mp3.wav.wav'
audio_path_m_1 = './REC20200222223334.mp3.wav.wav'
audio_path_m_2 = './REC20200222223350.mp3.wav.wav'
audio_path_m_3 = './REC20200222223431.mp3.wav.wav'
audio_path_f   = './REC20200222223500.mp3.wav.wav'
x_m , sr_m = librosa.load(audio_path_m,sr=None)
print(x_m, sr_m)
x_m_1 , sr_m_1 = librosa.load(audio_path_m_1,sr=None)
print(x_m_1, sr_m_1)
x_m_2 , sr_m_2 = librosa.load(audio_path_m_2,sr=None)
print(x_m_2, sr_m_2)
x_m_3 , sr_m_3 = librosa.load(audio_path_m_3,sr=None)
print(x_m_3, x_m_3)
x_f , sr_f = librosa.load(audio_path_f,sr=None)
print(x_f, sr_f)


#display waveform
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x_m, sr=sr_m)
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x_m_1, sr=sr_m_1)
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x_m_2, sr=sr_m_2)
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x_m_3, sr=sr_m_3)
plt.figure(figsize=(14, 5))
# librosa.display.waveplot(x_m_4, sr=None)
# plt.figure(figsize=(14, 5))
librosa.display.waveplot(x_f, sr=sr_f)

#display Spectrogram
X = librosa.stft(x_m)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr_m, x_axis='time', y_axis='hz') 
#If to pring log of frequencies  
#librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

#display Spectrogram
X = librosa.stft(x_m_1)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr_m_1, x_axis='time', y_axis='hz') 
#If to pring log of frequencies  
#librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

#display Spectrogram
X = librosa.stft(x_m_2)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr_m_2, x_axis='time', y_axis='hz') 
#If to pring log of frequencies  
#librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()


#display Spectrogram
X = librosa.stft(x_m_3)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr_m_3, x_axis='time', y_axis='hz') 
#If to pring log of frequencies  
#librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

# #display Spectrogram
# X = librosa.stft(x_m_4)
# Xdb = librosa.amplitude_to_db(abs(X))
# plt.figure(figsize=(14, 5))
# librosa.display.specshow(Xdb, sr=sr_m_4, x_axis='time', y_axis='hz') 
# #If to pring log of frequencies  
# #librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
# plt.colorbar()


#display Spectrogram
X = librosa.stft(x_f)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr_f, x_axis='time', y_axis='hz') 
#If to pring log of frequencies  
#librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()
# Out:
# [ 0.          0.          0.         ... -0.00512695 -0.00889587
#  -0.01448059] 48000
# [ 0.          0.          0.         ... -0.01092529 -0.0087738
#  -0.00848389] 48000
# [ 0.          0.          0.         ... -0.02319336 -0.01959229
#  -0.01551819] 48000
# [0.         0.         0.         ... 0.0043335  0.00421143 0.00230408] [0.         0.         0.         ... 0.0043335  0.00421143 0.00230408]
# [0.         0.         0.         ... 0.01797485 0.01824951 0.01809692] 48000

# %%
mfccs = librosa.feature.mfcc(x_m, sr=sr_m,n_mfcc=13)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr_m, x_axis='time',cmap='gray_r')
# Out:
# (13, 178)

# %%
mfccs = librosa.feature.mfcc(x_m_1, sr=sr_m_1,n_mfcc=13)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr_m_1, x_axis='time',cmap='gray_r')
# Out:
# (13, 172)

# %%
mfccs = librosa.feature.mfcc(x_m_2, sr=sr_m_2,n_mfcc=13)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr_m_2, x_axis='time',cmap='gray_r')
# Out:
# (13, 221)

# %%
mfccs = librosa.feature.mfcc(x_m_3, sr=sr_m_3,n_mfcc=13)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr_m_3, x_axis='time',cmap='gray_r')
# Out:
# (13, 205)

# %%
mfccs = librosa.feature.mfcc(x_f, sr=sr_f,n_mfcc=13)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr_f, x_axis='time',cmap='gray_r')
# Out:
# (13, 122)

# %%
mfccs = librosa.feature.mfcc(x_m, sr=sr_m_1,n_mfcc=5)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr_m, x_axis='time',cmap='gray_r')
# Out:
# (5, 178)

# %%
mfccs = librosa.feature.mfcc(x_m_2, sr=sr_m_2,n_mfcc=5)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr_m_2, x_axis='time',cmap='gray_r')
# Out:
# (5, 221)

# %%
mfccs = librosa.feature.mfcc(x_m_3, sr=sr_m_3,n_mfcc=5)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr_m_3, x_axis='time',cmap='gray_r')
# Out:
# (5, 205)

# %%
mfccs = librosa.feature.mfcc(x_f, sr=sr_f,n_mfcc=5)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr_f, x_axis='time',cmap='gray_r')
# Out:
# (5, 122)

# %%
mfccs = librosa.feature.mfcc(x_m, sr=sr_m,n_mfcc=5)
print(mfccs.shape)
#Displaying  the MFCCs:
librosa.display.specshow(mfccs, sr=sr_m, x_axis='time',cmap='gray_r')
# Out:
# (5, 178)
